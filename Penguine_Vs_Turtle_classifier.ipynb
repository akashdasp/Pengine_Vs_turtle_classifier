# %% [markdown]
# #### Unziping the Image Datasets

# %%
import zipfile

# Specify the path to the zip file
zip_file_path = '/content/archive.zip'

# Specify the directory where you want to extract the files
extract_dir = '/content/archive/'

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the files to the specified directory
    zip_ref.extractall(extract_dir)

print("Extraction completed.")
# Out:
# Extraction completed.

# %%
import pandas as pd
import numpy as np
from numpy import random
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import time
import matplotlib
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
import shutil
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import albumentations as A
import time
from tqdm import tqdm
from sklearn.metrics import f1_score
#from IPython.display import YouTubeVideo
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
# Seed Everything to reproduce results for future use cases
def seed_everything(seed=42):
    # Seed value for TensorFlow
    tf.random.set_seed(seed)

    # Seed value for NumPy
    np.random.seed(seed)

    # Seed value for Python's random library
    random.seed(seed)

    # Force TensorFlow to use single thread
    # Multiple threads are a potential source of non-reproducible results.
    session_conf = tf.compat.v1.ConfigProto(
        intra_op_parallelism_threads=1,
        inter_op_parallelism_threads=1
    )

    # Make sure that TensorFlow uses a deterministic operation wherever possible
    tf.compat.v1.set_random_seed(seed)

    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

seed_everything()

# %%
train_anno=pd.read_json('/content/archive/train_annotations')
train_anno.head()
# Out:
#    id  image_id  category_id                  bbox    area segmentation  \
# 0   0         0            1   [119, 25, 205, 606]  124230           []
# 1   1         1            1   [131, 82, 327, 440]  143880           []
# 2   2         2            2  [225, 298, 198, 185]   36630           []
# 3   3         3            2  [468, 109, 172, 193]   33196           []
# 4   4         4            1   [14, 242, 611, 154]   94094           []
#
#    iscrowd
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# lets see how many classes are present in the category id
classes=list(train_anno['category_id'].unique())
print (classes)
# for image_id 0 image is of a penguin so class 1 indicates a penguin, class 2 indicates a turtle
# I will not be using columns id, bbox, area, segmentation or iscrowd so lets delete the columns
train_anno=train_anno.drop(['id', 'bbox', 'area', 'segmentation', 'iscrowd'], axis =1)
# lets replace the numeric class designation with the test name of the class
train_anno['category_id']=train_anno['category_id'].replace({1:'Penguin',2:'Turtle'})
print (train_anno.head())
# I want to create a dataframe with 2 columns filepaths and labels where the entries in the filepaths
# column is the full path to the image file and the entries in the labels column is the text label of
# of the class
# first lets change the column names
train_anno.columns=['filepaths', 'labels']
print(train_anno.head())
# now in the filepaths column create the full path to the image file
train_image_dir='/content/archive/train/train'
train_imglist=sorted(os.listdir(train_image_dir))
train_paths=[]
for i in range (len(train_imglist)):
    train_paths.append(os.path.join(train_image_dir, train_imglist[i]))
print (train_paths[0])
# now in the train_anno filepaths column insert the full filepath
train_anno['filepaths']=train_paths
print (train_anno.head())
# Out:
# [1, 2]
#    image_id category_id
# 0         0     Penguin
# 1         1     Penguin
# 2         2      Turtle
# 3         3      Turtle
# 4         4     Penguin
#    filepaths   labels
# 0          0  Penguin
# 1          1  Penguin
# 2          2   Turtle
# 3          3   Turtle
# 4          4  Penguin
# /content/archive/train/train/image_id_000.jpg
#                                        filepaths   labels
# 0  /content/archive/train/train/image_id_000.jpg  Penguin
# 1  /content/archive/train/train/image_id_001.jpg  Penguin
# 2  /content/archive/train/train/image_id_002.jpg   Turtle
# 3  /content/archive/train/train/image_id_003.jpg   Turtle
# 4  /content/archive/train/train/image_id_004.jpg  Penguin

# %%
# Do the same for the valid annotations
valid_df=pd.read_json('/content/archive/valid_annotations')
valid_df=valid_df.drop(['id', 'bbox', 'area', 'segmentation', 'iscrowd'], axis =1)
# lets replace the numeric class designation with the test name of the class
valid_df['category_id']=valid_df['category_id'].replace({1:'Penguin',2:'Turtle'})
valid_df.columns=['filepaths', 'labels']
# now in the filepaths column create the full path to the image file
valid_image_dir=r'/content/archive/valid/valid'
valid_imglist=sorted(os.listdir(valid_image_dir))
valid_paths=[]
for i in range (len(valid_imglist)):
    valid_paths.append(os.path.join(valid_image_dir, valid_imglist[i]))
valid_df['filepaths']=valid_paths
print (valid_df.head())
# Out:
#                                        filepaths   labels
# 0  /content/archive/valid/valid/image_id_000.jpg  Penguin
# 1  /content/archive/valid/valid/image_id_001.jpg   Turtle
# 2  /content/archive/valid/valid/image_id_002.jpg   Turtle
# 3  /content/archive/valid/valid/image_id_003.jpg  Penguin
# 4  /content/archive/valid/valid/image_id_004.jpg  Penguin

# %%
# lets create a test data frame by splitting the train_anno dataframe into a train dataframe and a test data frame
train_df, test_df=train_test_split(train_anno, train_size=.8, shuffle=True, random_state=123,
                                   stratify=train_anno['labels'])
print ('train_df lenght: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df lenght:  400   test_df length:  100   valid_df length:  72

# %%
# lets check the balance of labels in the dataset
balance=list(train_df['labels'].value_counts())
print (balance)
# Out:
# [200, 200]

# %%
test_df
# Out:
#                                          filepaths   labels
# 144  /content/archive/train/train/image_id_144.jpg  Penguin
# 414  /content/archive/train/train/image_id_414.jpg   Turtle
# 226  /content/archive/train/train/image_id_226.jpg  Penguin
# 209  /content/archive/train/train/image_id_209.jpg   Turtle
# 494  /content/archive/train/train/image_id_494.jpg   Turtle
# 200  /content/archive/train/train/image_id_200.jpg  Penguin
# 426  /content/archive/train/train/image_id_426.jpg   Turtle
# 457  /content/archive/train/train/image_id_457.jpg   Turtle
# 89   /content/archive/train/train/image_id_089.jpg  Penguin
# 303  /content/archive/train/train/image_id_303.jpg   Turtle
# 4    /content/archive/train/train/image_id_004.jpg  Penguin
# 357  /content/archive/train/train/image_id_357.jpg  Penguin
# 101  /content/archive/train/train/image_id_101.jpg   Turtle
# 233  /content/archive/train/train/image_id_233.jpg   Turtle
# 467  /content/archive/train/train/image_id_467.jpg  Penguin
# 283  /content/archive/train/train/image_id_283.jpg   Turtle
# 275  /content/archive/train/train/image_id_275.jpg   Turtle
# 496  /content/archive/train/train/image_id_496.jpg  Penguin
# 247  /content/archive/train/train/image_id_247.jpg   Turtle
# 462  /content/archive/train/train/image_id_462.jpg   Turtle
# 474  /content/archive/train/train/image_id_474.jpg   Turtle
# 438  /content/archive/train/train/image_id_438.jpg  Penguin
# 296  /content/archive/train/train/image_id_296.jpg   Turtle
# 362  /content/archive/train/train/image_id_362.jpg  Penguin
# 333  /content/archive/train/train/image_id_333.jpg   Turtle
# 317  /content/archive/train/train/image_id_317.jpg   Turtle
# 245  /content/archive/train/train/image_id_245.jpg   Turtle
# 289  /content/archive/train/train/image_id_289.jpg   Turtle
# 254  /content/archive/train/train/image_id_254.jpg   Turtle
# 450  /content/archive/train/train/image_id_450.jpg  Penguin
# 99   /content/archive/train/train/image_id_099.jpg  Penguin
# 118  /content/archive/train/train/image_id_118.jpg  Penguin
# 242  /content/archive/train/train/image_id_242.jpg  Penguin
# 205  /content/archive/train/train/image_id_205.jpg   Turtle
# 423  /content/archive/train/train/image_id_423.jpg  Penguin
# 201  /content/archive/train/train/image_id_201.jpg  Penguin
# 163  /content/archive/train/train/image_id_163.jpg   Turtle
# 342  /content/archive/train/train/image_id_342.jpg   Turtle
# 280  /content/archive/train/train/image_id_280.jpg  Penguin
# 167  /content/archive/train/train/image_id_167.jpg  Penguin
# 412  /content/archive/train/train/image_id_412.jpg   Turtle
# 435  /content/archive/train/train/image_id_435.jpg  Penguin
# 445  /content/archive/train/train/image_id_445.jpg  Penguin
# 187  /content/archive/train/train/image_id_187.jpg  Penguin
# 109  /content/archive/train/train/image_id_109.jpg   Turtle
# 178  /content/archive/train/train/image_id_178.jpg   Turtle
# 168  /content/archive/train/train/image_id_168.jpg   Turtle
# 32   /content/archive/train/train/image_id_032.jpg  Penguin
# 253  /content/archive/train/train/image_id_253.jpg  Penguin
# 220  /content/archive/train/train/image_id_220.jpg  Penguin
# 3    /content/archive/train/train/image_id_003.jpg   Turtle
# 189  /content/archive/train/train/image_id_189.jpg  Penguin
# 62   /content/archive/train/train/image_id_062.jpg  Penguin
# 214  /content/archive/train/train/image_id_214.jpg  Penguin
# 72   /content/archive/train/train/image_id_072.jpg  Penguin
# 451  /content/archive/train/train/image_id_451.jpg  Penguin
# 31   /content/archive/train/train/image_id_031.jpg   Turtle
# 10   /content/archive/train/train/image_id_010.jpg   Turtle
# 223  /content/archive/train/train/image_id_223.jpg  Penguin
# 262  /content/archive/train/train/image_id_262.jpg  Penguin
# 153  /content/archive/train/train/image_id_153.jpg  Penguin
# 166  /content/archive/train/train/image_id_166.jpg   Turtle
# 485  /content/archive/train/train/image_id_485.jpg  Penguin
# 321  /content/archive/train/train/image_id_321.jpg   Turtle
# 47   /content/archive/train/train/image_id_047.jpg   Turtle
# 131  /content/archive/train/train/image_id_131.jpg   Turtle
# 370  /content/archive/train/train/image_id_370.jpg  Penguin
# 193  /content/archive/train/train/image_id_193.jpg   Turtle
# 464  /content/archive/train/train/image_id_464.jpg   Turtle
# 252  /content/archive/train/train/image_id_252.jpg  Penguin
# 196  /content/archive/train/train/image_id_196.jpg  Penguin
# 381  /content/archive/train/train/image_id_381.jpg  Penguin
# 206  /content/archive/train/train/image_id_206.jpg  Penguin
# 319  /content/archive/train/train/image_id_319.jpg   Turtle
# 456  /content/archive/train/train/image_id_456.jpg   Turtle
# 410  /content/archive/train/train/image_id_410.jpg   Turtle
# 179  /content/archive/train/train/image_id_179.jpg   Turtle
# 198  /content/archive/train/train/image_id_198.jpg  Penguin
# 322  /content/archive/train/train/image_id_322.jpg   Turtle
# 84   /content/archive/train/train/image_id_084.jpg  Penguin
# 70   /content/archive/train/train/image_id_070.jpg   Turtle
# 316  /content/archive/train/train/image_id_316.jpg  Penguin
# 127  /content/archive/train/train/image_id_127.jpg   Turtle
# 132  /content/archive/train/train/image_id_132.jpg   Turtle
# 497  /content/archive/train/train/image_id_497.jpg  Penguin
# 172  /content/archive/train/train/image_id_172.jpg  Penguin
# 341  /content/archive/train/train/image_id_341.jpg  Penguin
# 183  /content/archive/train/train/image_id_183.jpg   Turtle
# 162  /content/archive/train/train/image_id_162.jpg   Turtle
# 207  /content/archive/train/train/image_id_207.jpg   Turtle
# 351  /content/archive/train/train/image_id_351.jpg   Turtle
# 122  /content/archive/train/train/image_id_122.jpg  Penguin
# 473  /content/archive/train/train/image_id_473.jpg  Penguin
# 429  /content/archive/train/train/image_id_429.jpg   Turtle
# 215  /content/archive/train/train/image_id_215.jpg  Penguin
# 460  /content/archive/train/train/image_id_460.jpg  Penguin
# 105  /content/archive/train/train/image_id_105.jpg  Penguin
# 213  /content/archive/train/train/image_id_213.jpg   Turtle
# 413  /content/archive/train/train/image_id_413.jpg   Turtle
# 390  /content/archive/train/train/image_id_390.jpg  Penguin

# %%
# the train set is balance and has an adequate number of images for classification
# lets create generators for the three dataframes
img_size=(224,224) # image size
bs=40 # batch size
t_gen=ImageDataGenerator(horizontal_flip=True) # generator for training
gen=ImageDataGenerator() # generator for validation and test
train_gen=t_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   color_mode='rgb',batch_size=bs, shuffle=True, seed=123,
                                   class_mode= 'categorical')
valid_gen=gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   color_mode='rgb',batch_size=bs, shuffle=False, seed=123,
                                   class_mode= 'categorical')
test_gen=gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   color_mode='rgb',batch_size=bs, shuffle=False, seed=123,
                                   class_mode= 'categorical')
# Out:
# Found 400 validated image filenames belonging to 2 classes.
# Found 72 validated image filenames belonging to 2 classes.
# Found 100 validated image filenames belonging to 2 classes.

# %%
# I will use transfer learning using the EfficientNetB0 model
class_count=2 # number of classes
lr= .001 # learning rate
img_shape=(224,224,3) # shape of color images
base_model=tf.keras.applications.EfficientNetV2B0(include_top=False, weights="imagenet",
                                                   input_shape=img_shape, pooling='max')
base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 [==============================] - 1s 0us/step

# %%
# lets define 2 callbacks , reduce learning rate on plateau and early stopping
rlronp=tf.keras.callbacks.ReduceLROnPlateau( monitor="val_loss", factor=0.4,  patience=2,
                                            verbose=1)
estop=tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=4,restore_best_weights=True)
callbacks=[rlronp, estop]

# %%
# now lets train the model
epochs=20
history=model.fit(x=train_gen,   epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
                   validation_steps=None,  shuffle=True,  initial_epoch=0) # train the model
# Out:
# Epoch 1/20
# 10/10 [==============================] - 70s 864ms/step - loss: 7.6057 - accuracy: 0.8625 - val_loss: 8.7404 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 2/20
# 10/10 [==============================] - 5s 499ms/step - loss: 6.6533 - accuracy: 0.9800 - val_loss: 7.6475 - val_accuracy: 0.9167 - lr: 0.0010
# Epoch 3/20
# 10/10 [==============================] - 4s 407ms/step - loss: 5.9708 - accuracy: 0.9975 - val_loss: 6.5446 - val_accuracy: 0.9444 - lr: 0.0010
# Epoch 4/20
# 10/10 [==============================] - 4s 398ms/step - loss: 5.4077 - accuracy: 0.9925 - val_loss: 5.7722 - val_accuracy: 0.9722 - lr: 0.0010
# Epoch 5/20
# 10/10 [==============================] - 5s 498ms/step - loss: 4.9051 - accuracy: 0.9975 - val_loss: 5.2027 - val_accuracy: 0.9722 - lr: 0.0010
# Epoch 6/20
# 10/10 [==============================] - 4s 430ms/step - loss: 4.4768 - accuracy: 0.9975 - val_loss: 4.7029 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 7/20
# 10/10 [==============================] - 5s 519ms/step - loss: 4.1114 - accuracy: 0.9950 - val_loss: 4.2765 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 8/20
# 10/10 [==============================] - 4s 402ms/step - loss: 3.7672 - accuracy: 0.9975 - val_loss: 3.8890 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 9/20
# 10/10 [==============================] - 5s 517ms/step - loss: 3.4805 - accuracy: 0.9975 - val_loss: 3.5933 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 10/20
# 10/10 [==============================] - 5s 497ms/step - loss: 3.2122 - accuracy: 0.9975 - val_loss: 3.3095 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 11/20
# 10/10 [==============================] - 4s 399ms/step - loss: 2.9866 - accuracy: 0.9975 - val_loss: 3.0896 - val_accuracy: 0.9306 - lr: 0.0010
# Epoch 12/20
# 10/10 [==============================] - 4s 409ms/step - loss: 2.7849 - accuracy: 0.9975 - val_loss: 2.8755 - val_accuracy: 0.9306 - lr: 0.0010
# Epoch 13/20
# 10/10 [==============================] - 5s 503ms/step - loss: 2.6204 - accuracy: 0.9925 - val_loss: 2.6881 - val_accuracy: 0.9444 - lr: 0.0010
# Epoch 14/20
# 10/10 [==============================] - 4s 410ms/step - loss: 2.4485 - accuracy: 1.0000 - val_loss: 2.5156 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 15/20
# 10/10 [==============================] - 4s 415ms/step - loss: 2.3026 - accuracy: 1.0000 - val_loss: 2.3761 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 16/20
# 10/10 [==============================] - 5s 531ms/step - loss: 2.1707 - accuracy: 0.9975 - val_loss: 2.2424 - val_accuracy: 0.9306 - lr: 0.0010
# Epoch 17/20
# 10/10 [==============================] - 4s 410ms/step - loss: 2.0467 - accuracy: 1.0000 - val_loss: 2.1237 - val_accuracy: 0.9306 - lr: 0.0010
# Epoch 18/20
# 10/10 [==============================] - 4s 405ms/step - loss: 1.9423 - accuracy: 0.9975 - val_loss: 2.0121 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 19/20
# 10/10 [==============================] - 5s 413ms/step - loss: 1.8377 - accuracy: 1.0000 - val_loss: 1.9164 - val_accuracy: 0.9583 - lr: 0.0010
# Epoch 20/20
# 10/10 [==============================] - 4s 401ms/step - loss: 1.7494 - accuracy: 1.0000 - val_loss: 1.8061 - val_accuracy: 0.9583 - lr: 0.0010

# %%
# lets define a function to plot the training data
def tr_plot(tr_data):
    start_epoch=0
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(25,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    plt.tight_layout
    plt.show()
    return

tr_plot(history)

# %%
# we ended up with a validation accuracy of 97.2 % so the model is performing well
# lets make predictions on the test set and produce a confusion matrix and a classification report
def predictor(model,test_gen):
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    preds=model.predict(test_gen, verbose=1)
    errors=0
    test_count =len(preds)
    misclassified_classes=[]
    misclassified_files=[]
    misclassified_as = []
    pred_indices=[]
    for i, p in enumerate (preds):
        pred_index=np.argmax(p)
        pred_indices.append(pred_index)
        true_index= test_gen.labels[i]
        if  pred_index != true_index:
            errors +=1
            misclassified_classes.append(classes[true_index])
            misclassified_as.append(classes[pred_index])
            file=test_gen.filenames[i]
            split=file.split('/')
            L=len(split)
            f=split[L-2] +' '+ split[L-1]
            misclassified_files.append(f)

    accuracy = (test_count-errors)*100/test_count
    ytrue=np.array(test_gen.labels)
    ypred=np.array(pred_indices)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    msg=f'There were {errors} errors in {test_count} tests for an accuracy of {accuracy:6.2f} and an F1 score of {f1score:6.2f}'
    print (msg)
    misclassified_classes=sorted(misclassified_classes)
    if len(misclassified_classes) > 0:
        misclassifications=[]
        for klass in misclassified_classes:
            mis_count=misclassified_classes.count(klass)
            misclassifications.append(mis_count)
        unique=len(np.unique(misclassified_classes))
        if unique==1:
            height=int(unique)
        else:
            height =int(unique/2)
        plt.figure(figsize=(10, height))
        plt.style.use('fivethirtyeight')
        plt.barh(misclassified_classes, misclassifications )
        plt.title( 'Classification Errors on Test Set by Class', fontsize=20, color='blue')
        plt.xlabel('NUMBER OF MISCLASSIFICATIONS', fontsize=20, color='blue')
        plt.ylabel('CLASS', fontsize=20, color='blue')
        plt.show()
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
        clr = classification_report(ytrue, ypred, target_names=classes, digits= 4) # create classification report
        print("Classification Report:\n----------------------\n", clr)
    return f1score, misclassified_files

f1score, misclassified_files= predictor(model,test_gen)
# Out:
# 3/3 [==============================] - 3s 614ms/step
# There were 1 errors in 100 tests for an accuracy of  99.00 and an F1 score of  99.00
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#      Penguin     1.0000    0.9800    0.9899        50
#       Turtle     0.9804    1.0000    0.9901        50
#
#     accuracy                         0.9900       100
#    macro avg     0.9902    0.9900    0.9900       100
# weighted avg     0.9902    0.9900    0.9900       100

# %% [markdown]
# ### In 100 tests we had only 2 errors so the accuracy on the test set was 98 %

# %%
# Lets save the model
def save_model(model,subject, classes, img_size, f1score, working_dir):
    name=f'{subject}-{str(len(classes))}-({str(img_size[0])} X {str(img_size[1])})- {f1score:5.2f}.h5'
    model_save_loc=os.path.join(working_dir, name)
    try:
        model.save(model_save_loc)
        msg= f'model was saved as {model_save_loc}'

    except:
        msg='model can not be saved due to tensorflow 2.10.0 or higher due to bug for efficientnet models'
    print (msg)
subject='penguins vs turtles'
working_dir=r'content/model/working/'
save_model(model,subject, classes, img_size, f1score, working_dir)
# Out:
# model was saved as content/model/working/penguins vs turtles-2-(224 X 224)- 99.00.h5

# %%
# now Load the model and Prdict the output for a perticular image Downlaoded from
# the Internet
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
#Loading the Saved Model
model = load_model('/content/content/model/working/penguins vs turtles-2-(224 X 224)- 99.00.h5')
img_path = '/content/South_Shetland-2016-Deception_Island–Chinstrap_penguin_(Pygoscelis_antarctica)_04.jpg'  # Path to the input image file
img = image.load_img(img_path, target_size=(224, 224))  # Resize the image to match the model input size
img = image.img_to_array(img)  # Convert image to array
img = np.expand_dims(img, axis=0)  # Add an extra dimension to match the model input shape
img = img / 255.0  # Normalize the pixel values

prediction = model.predict(img)
# Out:
# 1/1 [==============================] - 2s 2s/step
# array([[0.44670224, 0.55329776]], dtype=float32)

# %%
"Pengine" if prediction.argmax() == 1 else "Turtle"
# Out:
# 'Pengine'

# %%
img_path = '/content/11e3bxo822_Sea_Turtle_Hol_Chan_Marine_Reserve_WW1105958.jpg'  # Path to the input image file
img = image.load_img(img_path, target_size=(224, 224))  # Resize the image to match the model input size
img = image.img_to_array(img)  # Convert image to array
img = np.expand_dims(img, axis=0)  # Add an extra dimension to match the model input shape
img = img / 255.0  # Normalize the pixel values
prediction=model.predict(img)
"Pengine" if prediction.argmax() == 1 else "Turtle"
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 'Pengine'

# %%
prediction
# Out:
# array([[0.44826353, 0.5517365 ]], dtype=float32)

# %%
img_path = '/content/download.jpg'  # Path to the input image file
img = image.load_img(img_path, target_size=(224, 224))  # Resize the image to match the model input size
img = image.img_to_array(img)  # Convert image to array
img = np.expand_dims(img, axis=0)  # Add an extra dimension to match the model input shape
img = img / 255.0  # Normalize the pixel values
prediction=model.predict(img)
print(prediction)
"Pengine" if prediction.argmax() == 1 else "Turtle"
# Out:
# 1/1 [==============================] - 0s 75ms/step
# [[0.44537902 0.554621  ]]
# 'Pengine'
